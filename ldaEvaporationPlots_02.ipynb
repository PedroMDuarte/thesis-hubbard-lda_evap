# %% [markdown]
# ## Unrestricted atom number

# %%
import optevap 

fig = optevap.plotOptimal_6( 'EtaF_data/026/wIRwGR_ETA_results.dat',\
        eta_contours = [1.9, 3.2, 6., 8., 10.],\
        delta_contours = [0.8, 1.6, 3.2, 6.4],\
        g0_contours  = [1.2, 2.0, 3.2, 3.8, 4.0],\
        sn_contours  = None, \
        hwhm_contours = None, \
        #[1.2, 1.4, 1.9, 2.4, 3.],\
        num_contours = [3., 6.],\
        xlim=(45.,71.),
        dashed_eta=[{'slope':1.07,'c':'black'}],\
        dashed_delta=[{'slope':1.07,'c':'black'}],\
        dashed_g0=[{'slope':1.0,'c':'black'}],\
        dashed_sn=[{'slope':0.98,'c':'black'}],\
        dashed_num=[{'slope':1.15,'c':'black'}], \
        dashed_hwhm=[{'slope':1.15,'c':'black'}] \
        )
fig.savefig('EtaF_data/026/etaF-wIRwGR.png', dpi=300)
# Out:
# /usr/lib/python2.7/dist-packages/numpy/lib/npyio.py:816: UserWarning: loadtxt: Empty input file: "EtaF_data/026/wIRwGR_ETA_results.dat"
#   warnings.warn('loadtxt: Empty input file: "%s"' % fname)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-ca913af44dd8> in <module>()
#       9         dashed_sn=[{'slope':0.98,'c':'black'}],\
#      10         dashed_num=[{'slope':1.15,'c':'black'}], \
# ---> 11         dashed_hwhm=[{'slope':1.15,'c':'black'}] \
#      12         )
#      13 fig.savefig('EtaF_data/026/etaF-wIRwGR.png', dpi=300)
#
# /home/pmd/sandbox/thesis04-hubbard-lda_evap/optevap.pyc in plotOptimal_6(datfile, **kwargs)
#     360     i=1; j=2; k=4
#     361     meshplot( ax,results, i, j, k, contours = eta_contours, \
# --> 362               dashed=dashed_eta , **kwargs)
#     363     ax.set_title('$\eta_{F}$', fontsize=16)
# ...

# %% [markdown]
# ## Unrestricted atom number, colder temperature T=0.2, blacked out portion of alpha

# %%
import optevap 

fig = optevap.plotOptimal_6( 'EtaF_data/017/wIRwGR_ETA_results.dat',\
        eta_contours = [3.2, 6., 8., 10.],\
        delta_contours = [0.8, 1.6, 3.2, 6.4],\
        g0_contours  = [1.2, 2.0, 3.2 ],\
        sn_contours  = None, \
        hwhm_contours = None, \
        #[1.2, 1.4, 1.9, 2.4, 3.],\
        num_contours = [3., 6.],\
        xlim=(45.,71.),
        dashed_eta=[{'slope':1.07,'c':'black'}],\
        dashed_delta=[{'slope':1.07,'c':'black'}],\
        dashed_g0=[{'slope':1.0,'c':'black'}],\
        dashed_sn=[{'slope':1.05,'c':'black'}],\
        dashed_num=[{'slope':1.15,'c':'black'}], \
        dashed_hwhm=[{'slope':1.15,'c':'black'}], \
        blackout = (1.24, 1.10)\
        )
fig.savefig('EtaF_data/017/etaF-wIRwGR.png', dpi=300)

# %% [markdown]
# ## Number fixed at 500,000, colder temperature T=0.2, blacked out portion of alpha

# %%
import optevap 

fig = optevap.plotOptimal_6( 'EtaF_data/018/wIRwGR_ETA_results.dat',\
        eta_contours = [3.2, 6., 8., 10.],\
        delta_contours = [0.8, 1.6, 3.2, 6.4],\
        g0_contours  = [1.2, 2.0, 3.2 ],\
        sn_contours  = None, \
        hwhm_contours = None, \
        #[1.2, 1.4, 1.9, 2.4, 3.],\
        num_contours = [1.,2.,4.],\
        xlim=(45.,71.),
        dashed_eta=[{'slope':1.00,'c':'black'}],\
        dashed_delta=[{'slope':1.00,'c':'black'}],\
        dashed_g0=None,\
        dashed_sn=[{'slope':1.00,'c':'black'}],\
        dashed_num=[{'slope':1.16,'c':'black'},{'slope':1.00,'c':'black'}], \
        dashed_hwhm=[{'slope':1.16,'c':'black'},{'slope':1.00,'c':'black'}], \
        blackout = (1.24, 1.10)\
        )
fig.savefig('EtaF_data/018/etaF-wIRwGR.png', dpi=300)

# %% [markdown]
# ## Line plot of wIR for $\alpha=1$ optimized at fixed atom number N=500,000

# %%
# ORDER OF THE COLUMNS IS 
# 0   s0
# 1   wL
# 2   wG
# 3   g0
# 4   etaF
# 5   N
# 6   S/N
# 7   radius
# 8   rfactor
# 9   deltaF


from matplotlib import rc
rc('font',**{'family':'serif'})
rc('text', usetex=True)

fig = plt.figure(figsize=(9.,4.9))
gs  = matplotlib.gridspec.GridSpec(2,3, wspace=0.3, hspace=0.35,\
        left=0.06, right=0.98, bottom=0.12, top=0.95)


axL = [ fig.add_subplot( gs[i] ) for i in range(6) ] 


color = ['blue', 'green', 'red', 'black']
i=0    
    
dat = np.loadtxt('EtaF_data/019/wIRwGR_ETA_results.dat') 

cols = [4, 9, 3, 6, 5, 8] 
base = [1., 1., 1., 1., 1e5, 1.]
for j,c in enumerate(cols):
    
    axL[j].plot( dat[:,2], dat[:,c]/base[j], 'o-', ms=3)

YLAB = [ '$\eta_{F}$', '$\Delta_{F}$', '$g_{0}$', '$S/N$', '$N/10^{5}$', '$\mathrm{HWHM}/w_{L}$']
    
for i,ax in enumerate(axL):
    ax.set_xlabel('$\mathrm{Compensation\ waist}\ w_{C}\ (\mu\mathrm{m})$')
    ax.set_ylabel( YLAB[i] ) 
    ax.grid()

#axL[1].legend( bbox_to_anchor = (0.,1.), loc='upper left', \
#        numpoints=1, labelspacing=0.2, prop={'size':10},\
#        handlelength=1.1, handletextpad=0.5 )


fig.savefig('EtaF_data/019/etaF_wIRwGR.png', dpi=300)

# %% [markdown]
# ## Line plot for $\alpha$ at fixed wIR,  optimized at N=500,000

# %%
# ORDER OF THE COLUMNS IS 
# 0   s0
# 1   wL
# 2   wG
# 3   g0
# 4   etaF
# 5   N
# 6   S/N
# 7   radius
# 8   rfactor
# 9   deltaF
# 10  alpha
# 11  T 


from matplotlib import rc
rc('font',**{'family':'serif'})
rc('text', usetex=True)

fig = plt.figure(figsize=(9.,4.9))
gs  = matplotlib.gridspec.GridSpec(2,3, wspace=0.3, hspace=0.35,\
        left=0.06, right=0.98, bottom=0.12, top=0.95)


axL = [ fig.add_subplot( gs[i] ) for i in range(6) ] 


color = ['blue', 'green', 'red', 'black']
i=0    
    
dat = np.loadtxt('EtaF_data/020/wIRwGR_ETA_results.dat') 

Ts = np.unique( dat[:, 11] ) 

for T in Ts:
    Tdat = dat[  dat[:,11] == T ] 
    cols = [4, 9, 3, 6, 5, 8] 
    base = [1., 1., 1., 1., 1e5, 1.]
    for j,c in enumerate(cols):
        if j == 2:
            label = '$T=%.1f\,E_{R}$'%T
            axL[j].plot( Tdat[:,10], Tdat[:,c]/base[j], 'o-', ms=3, label=label)
        else:
            axL[j].plot( Tdat[:,10], Tdat[:,c]/base[j], 'o-', ms=3)

    
YLAB = [ '$\eta_{F}$', '$\Delta_{F}$', '$g_{0}$', '$S/N$', '$N/10^{5}$', '$\mathrm{HWHM}/w_{L}$']        
for i,ax in enumerate(axL):
    ax.set_xlabel('$\mathrm{Compensation\ waist}\ w_{C}\ (\mu\mathrm{m})$')
    ax.set_ylabel( YLAB[i] ) 
    ax.grid()

axL[2].legend( bbox_to_anchor = (0.,0.), loc='lower left', \
        numpoints=1, labelspacing=0.2, prop={'size':10},\
        handlelength=1.1, handletextpad=0.5 )


fig.savefig('EtaF_data/020/etaF_wIRwGR.png', dpi=300)

# %% [markdown]
# ## Line plot for $\alpha$ at fixed wIR,  unrestricted atom number

# %%
# ORDER OF THE COLUMNS IS 
# 0   s0
# 1   wL
# 2   wG
# 3   g0
# 4   etaF
# 5   N
# 6   S/N
# 7   radius
# 8   rfactor
# 9   deltaF
# 10  alpha
# 11  T 


from matplotlib import rc
rc('font',**{'family':'serif'})
rc('text', usetex=True)




color = ['blue', 'green', 'red', 'black']
#i=0    
    
dat = np.loadtxt('EtaF_data/021/wIRwGR_ETA_results.dat') 

Ts = np.unique( dat[:, 11] ) 
Ts = [0.1, 0.2, 0.3, 0.4]

for T in Ts:
    
    fig = plt.figure(figsize=(9.,4.9))
    gs  = matplotlib.gridspec.GridSpec(2,3, wspace=0.3, hspace=0.35,\
            left=0.06, right=0.98, bottom=0.12, top=0.95)
    
    
    axL = [ fig.add_subplot( gs[i] ) for i in range(6) ] 
    
    Tdat = dat[  dat[:,11] == T ] 
    wIRs = np.unique( dat[:,1] ) 
    #wIRs = [47., 50., 55., 60.] 
    for wIR in wIRs:
        wdat = Tdat[ Tdat[:,1] == wIR ] 
        
        #print np.unique(wdat[:,10])
            
        cols = [4, 9, 3, 6, 5, 8] 
        base = [1., 1., 1., 1., 1e5, 1.]
        for j,c in enumerate(cols):
            if j == 4:
                #label = '$T=%.1f\,E_{R}$'%T
                label = '$w_{L}=%d\,\mu\mathrm{m}$'%wIR
                axL[j].plot( wdat[:,10], wdat[:,c]/base[j], 'o-', ms=3, label=label)
            else:
                if wIR == 45:
                    axL[j].plot( wdat[:,10], wdat[:,c]/base[j], 'o-', color='black', ms=3)

    
    YLAB = [ '$\eta_{F}$', '$\Delta_{F}$', '$g_{0}$', '$S/N$', '$N/10^{5}$', '$\mathrm{HWHM}/w_{L}$']        
    for i,ax in enumerate(axL):
        ax.set_xlabel(r'$\alpha_{\mathrm{w}}$')
        ax.set_xlim(0.85,1.22)
        ax.set_ylabel( YLAB[i] ) 
        ax.grid()
    
    axL[4].set_ylim(0.,10.)
    axL[4].legend( bbox_to_anchor = (0.,1.1), loc='upper left', \
            numpoints=1, labelspacing=0.2, prop={'size':8},\
            handlelength=1.1, handletextpad=0.5 )
    
    
    fig.savefig('EtaF_data/021/etaF_wIRwGR_T%02d_alpha.png'%(10.*T), dpi=300)

# %% [markdown]
# ## Entropy as a function of $\alpha$ for various temperatures

# %%
# ORDER OF THE COLUMNS IS 
# 0   s0
# 1   wL
# 2   wG
# 3   g0
# 4   etaF
# 5   N
# 6   S/N
# 7   radius
# 8   rfactor
# 9   deltaF
# 10  alpha
# 11  T 


from matplotlib import rc
rc('font',**{'family':'serif'})
rc('text', usetex=True)

fig = plt.figure(figsize=(3.2,2.5))
gs  = matplotlib.gridspec.GridSpec(1,1, wspace=0.3, hspace=0.35,\
        left=0.16, right=0.9, bottom=0.16, top=0.95)


ax =  fig.add_subplot( gs[0] ) 


color = ['blue', 'green', 'red', 'black']
i=0    
    
dat = np.loadtxt('EtaF_data/021/wIRwGR_ETA_results.dat') 

Ts = np.unique( dat[:, 11] ) 
Ts = [0.1, 0.2] 

for T in Ts:
    Tdat = dat[  dat[:,11] == T ] 
    wIR = 50. 
    wdat = Tdat[ Tdat[:,1] == wIR ] 
    
    col = 6 
    base = 1.0 #wdat[:,col].max()
    label = '$T=%.1f\,E_{R}$'%T
    ax.plot( wdat[:,10], wdat[:,col]/base, 'o-', ms=3, label=label)
    
    
YLAB ='$S/N$'       
ax.set_xlabel(r'$\alpha_{\mathrm{w}}$')
ax.set_xlim(0.85,1.22)
ax.set_ylabel( YLAB ) 
ax.grid()

ax.legend( bbox_to_anchor = (1.12,1.08), loc='upper right', \
        numpoints=1, labelspacing=0.2, prop={'size':10},\
        handlelength=1.1, handletextpad=0.5 )


fig.savefig('EtaF_data/021/SN_T.png', dpi=300)

# %% [markdown]
# ## Line plot for $\alpha$ at fixed wIR,  unrestricted atom number, scattering length 300a0

# %%
# ORDER OF THE COLUMNS IS 
# 0   s0
# 1   wL
# 2   wG
# 3   g0
# 4   etaF
# 5   N
# 6   S/N
# 7   radius
# 8   rfactor
# 9   deltaF
# 10  alpha
# 11  T 


from matplotlib import rc
rc('font',**{'family':'serif'})
rc('text', usetex=True)




color = ['blue', 'green', 'red', 'black']
#i=0    
    
dat = np.loadtxt('EtaF_data/022/wIRwGR_ETA_results.dat') 

Ts = np.unique( dat[:, 11] ) 
Ts = [0.1, 0.2, 0.3, 0.4]

for T in Ts:
    
    fig = plt.figure(figsize=(9.,4.9))
    gs  = matplotlib.gridspec.GridSpec(2,3, wspace=0.3, hspace=0.35,\
            left=0.06, right=0.98, bottom=0.12, top=0.95)
    
    
    axL = [ fig.add_subplot( gs[i] ) for i in range(6) ] 
    
    Tdat = dat[  dat[:,11] == T ] 
    wIRs = np.unique( dat[:,1] ) 
    #wIRs = [47., 50., 55., 60.] 
    for wIR in wIRs:
        wdat = Tdat[ Tdat[:,1] == wIR ] 
        
        #print np.unique(wdat[:,10])
            
        cols = [4, 9, 3, 6, 5, 8] 
        base = [1., 1., 1., 1., 1e5, 1.]
        for j,c in enumerate(cols):
            if j == 4:
                #label = '$T=%.1f\,E_{R}$'%T
                label = '$w_{L}=%d\,\mu\mathrm{m}$'%wIR
                axL[j].plot( wdat[:,10], wdat[:,c]/base[j], 'o-', ms=3, label=label)
            else:
                if wIR == 45:
                    axL[j].plot( wdat[:,10], wdat[:,c]/base[j], 'o-', color='black', ms=3)

    
    YLAB = [ '$\eta_{F}$', '$\Delta_{F}$', '$g_{0}$', '$S/N$', '$N/10^{5}$', '$\mathrm{HWHM}/w_{L}$']        
    for i,ax in enumerate(axL):
        ax.set_xlabel(r'$\alpha_{\mathrm{w}}$')
        ax.set_xlim(0.85,1.22)
        ax.set_ylabel( YLAB[i] ) 
        ax.grid()
    
    axL[4].set_ylim(0.,10.)
    axL[4].legend( bbox_to_anchor = (0.,1.1), loc='upper left', \
            numpoints=1, labelspacing=0.2, prop={'size':8},\
            handlelength=1.1, handletextpad=0.5 )
    
    
    fig.savefig('EtaF_data/022/etaF_wIRwGR_T%02d_alpha_300a0.png'%(10.*T), dpi=300)

# %% [markdown]
# ## For fixed $w_{L}$, $\alpha$, vary the compensation to verify that $\eta_{F}$ and $\Delta_{F}$ are minimized simultaneously

# %%
# ORDER OF THE COLUMNS IS 
# 0   s0
# 1   wL
# 2   wG
# 3   g0
# 4   etaF
# 5   N
# 6   S/N
# 7   radius
# 8   rfactor
# 9   deltaF
# 10  alpha
# 11  T 


from matplotlib import rc
rc('font',**{'family':'serif'})
rc('text', usetex=True)


color = ['blue', 'green', 'red', 'black']
#i=0    
    
dat = np.loadtxt('EtaF_data/023/wIRwGR_ETA_results.dat') 

    
fig = plt.figure(figsize=(9.,4.9))
gs  = matplotlib.gridspec.GridSpec(2,3, wspace=0.3, hspace=0.35,\
        left=0.06, right=0.98, bottom=0.12, top=0.95)


axL = [ fig.add_subplot( gs[i] ) for i in range(6) ] 


alphas = np.unique( dat[:,10] ) 
for alpha in alphas:
    adat = dat[ dat[:,10] == alpha ]  
    adat = adat[ adat[:,3] > 
        
    cols = [4, 9, 3, 6, 5, 8] 
    base = [1., 1., 1., 1., 1e5, 1.]
    for j,c in enumerate(cols):
        if j == 4:
            label = r'$\alpha_{w}=%.2f$'%alpha
            axL[j].plot( adat[:,3], adat[:,c]/base[j], 'o-', ms=3, label=label)
        else:
            axL[j].plot( adat[:,3], adat[:,c]/base[j], 'o-', ms=3)


YLAB = [ '$\eta_{F}$', '$\Delta_{F}$', '$g_{0}$', '$S/N$', '$N/10^{5}$', '$\mathrm{HWHM}/w_{L}$']        
for i,ax in enumerate(axL):
    ax.set_xlabel(r'$g_{0}$')
    ax.set_xlim(2.0, 4.5)
    ax.set_ylabel( YLAB[i] ) 
    ax.grid()

axL[4].set_ylim(0.,8.)
axL[4].legend( bbox_to_anchor = (0.,1.1), loc='upper left', \
        numpoints=1, labelspacing=0.2, prop={'size':8},\
        handlelength=1.1, handletextpad=0.5 )


fig.savefig('EtaF_data/023/etaF_wIRwGR_g0.png', dpi=300)

# %% [markdown]
# ## For fixed $w_{L}$, $\alpha$, vary the temperature to see how much it affects atom number

# %%
# ORDER OF THE COLUMNS IS 
# 0   s0
# 1   wL
# 2   wG
# 3   g0
# 4   etaF
# 5   N
# 6   S/N
# 7   radius
# 8   rfactor
# 9   deltaF
# 10  alpha
# 11  T 


from matplotlib import rc
rc('font',**{'family':'serif'})
rc('text', usetex=True)


color = ['blue', 'green', 'red', 'black']
#i=0    
    
dat = np.loadtxt('EtaF_data/024/wIRwGR_ETA_results.dat') 

    
fig = plt.figure(figsize=(9.,4.9))
gs  = matplotlib.gridspec.GridSpec(2,3, wspace=0.3, hspace=0.35,\
        left=0.06, right=0.98, bottom=0.12, top=0.95)


axL = [ fig.add_subplot( gs[i] ) for i in range(6) ] 

wIRs = np.unique( dat[:,1] )

for wIR in wIRs:
    wdat = dat[ dat[:,1] == wIR ] 
    
    cols = [4, 9, 3, 6, 5, 8] 
    base = [1., 1., 1., 1., 1e5, 1.]
    for j,c in enumerate(cols):
        if j == 4:
            label = r'$w_{L}=%d\,\mu\mathrm{m}$'%wIR
            axL[j].plot( wdat[:,11] *10.1/0.4, wdat[:,c]/base[j], 'o-', ms=3, label=label)
        else:
            axL[j].plot( wdat[:,11] *10.1/0.4, wdat[:,c]/base[j], 'o-', ms=3)


YLAB = [ '$\eta_{F}$', '$\Delta_{F}$', '$g_{0}$', '$S/N$', '$N/10^{5}$', '$\mathrm{HWHM}/w_{L}$']        
for i,ax in enumerate(axL):
    ax.set_xlabel(r'$T/t$')
    #ax.set_xlim(2.0, 4.5)
    ax.set_ylabel( YLAB[i] ) 
    ax.grid()

axL[4].set_ylim(0.,8.)
axL[4].legend( bbox_to_anchor = (0.,1.1), loc='upper left', \
        numpoints=1, labelspacing=0.2, prop={'size':8},\
        handlelength=1.1, handletextpad=0.5 )


fig.savefig('EtaF_data/024/etaF_wIRwGR_Temperature.png', dpi=300)

# %%
# ORDER OF THE COLUMNS IS 
# 0   s0
# 1   wL
# 2   wG
# 3   g0
# 4   etaF
# 5   N
# 6   S/N
# 7   radius
# 8   rfactor
# 9   deltaF
# 10  alpha
# 11  T 


from matplotlib import rc
rc('font',**{'family':'serif'})
rc('text', usetex=True)


color = ['blue', 'green', 'red', 'black']
#i=0    
    
dat = np.loadtxt('EtaF_data/025/wIRwGR_ETA_results.dat') 

    
fig = plt.figure(figsize=(9.,4.9))
gs  = matplotlib.gridspec.GridSpec(2,3, wspace=0.3, hspace=0.35,\
        left=0.06, right=0.98, bottom=0.12, top=0.95)


axL = [ fig.add_subplot( gs[i] ) for i in range(6) ] 

wIRs = np.unique( dat[:,1] )

for wIR in wIRs:
    wdat = dat[ dat[:,1] == wIR ] 
    
    cols = [4, 9, 3, 6, 5, 8] 
    base = [1., 1., 1., 1., 1e5, 1.]
    for j,c in enumerate(cols):
        if j == 4:
            label = r'$w_{L}=%d\,\mu\mathrm{m}$'%wIR
            axL[j].plot( wdat[:,11] *10.1/0.4, wdat[:,c]/base[j], 'o-', ms=3, label=label)
        else:
            axL[j].plot( wdat[:,11] *10.1/0.4, wdat[:,c]/base[j], 'o-', ms=3)


YLAB = [ '$\eta_{F}$', '$\Delta_{F}$', '$g_{0}$', '$S/N$', '$N/10^{5}$', '$\mathrm{HWHM}/w_{L}$']        
for i,ax in enumerate(axL):
    ax.set_xlabel(r'$T/t$')
    #ax.set_xlim(2.0, 4.5)
    ax.set_ylabel( YLAB[i] ) 
    ax.grid()

axL[4].set_ylim(0.,12.)
axL[4].legend( bbox_to_anchor = (0.,1.1), loc='upper left', \
        numpoints=1, labelspacing=0.2, prop={'size':8},\
        handlelength=1.1, handletextpad=0.5 )


fig.savefig('EtaF_data/025/etaF_wIRwGR_Temperature.png', dpi=300)

# %% [markdown]
# ## Profiles

# %%
import scubic
import lda

profs = [ 
        #0  wIR=50, alpha=1.  along 111
        {'wIR':50.,\
         'wGR':50.,\
         'g0':4.24,\
         's0':7.,\
         'extents':80.,\
         'T':0.12,\
         'direc':'111'
        },
        #1  wIR=50, alpha=1.  along 100
        {'wIR':50.,\
         'wGR':50.,\
         'g0':4.24,\
         's0':7.,\
         'extents':80.,\
         'T':0.12,\
         'direc':'100'
        },
        #2  wIR=50, alpha=0.9  along 111
        {'wIR':50.,\
         'wGR':62.5,\
         'g0':4.24,\
         's0':7.,\
         'extents':80.,\
         'T':0.12,\
         'direc':'111'
        },
        #3  wIR=50, alpha=0.9  along 100
        {'wIR':50.,\
         'wGR':62.5,\
         'g0':4.24,\
         's0':7.,\
         'extents':80.,\
         'T':0.12,\
         'direc':'100'
        },
        #4  wIR=50, alpha=1.20  along 111
        {'wIR':50.,\
         'wGR':35.7143,\
         'g0':2.83,\
         's0':7.,\
         'extents':80.,\
         'T':0.12,\
         'direc':'111'
        },
        #5  wIR=50, alpha=1.30  along 100
        {'wIR':50.,\
         'wGR':38.461,\
         'g0':3.27,\
         's0':7.,\
         'extents':80.,\
         'T':0.12,\
         'direc':'111'
        },
        #6  wIR=50, alpha=0.5  along 111
        {'wIR':50.,\
         'wGR':100.,\
         'g0':4.28,\
         's0':7.,\
         'extents':80.,\
         'T':0.12,\
         'direc':'111'
        },
        #7  wIR=50, alpha=0.5  along 100
        {'wIR':50.,\
         'wGR':100.,\
         'g0':4.28,\
         's0':7.,\
         'extents':80.,\
         'T':0.12,\
         'direc':'100'
        },
        #8  wIR=55, alpha=1.05  along 111
        {'wIR':50.,\
         'wGR':50./1.05,\
         'g0':4.28,\
         's0':7.,\
         'aS':650.,\
         'extents':60.,\
         'T':0.10,\
         'direc':'111'
        },
        #9  wIR=55, alpha=1.05  along 111
        {'wIR':50.,\
         'wGR':50./1.05,\
         'g0':4.28,\
         's0':7.,\
         'aS':300.,\
         'extents':60.,\
         'T':0.10,\
         'direc':'111'
        },
        
        ]


tags = range(10) 


for tag in tags:
    print '\n',tag

    s       = profs[tag]['s0']
    g       = profs[tag]['g0']
    wIR     = profs[tag]['wIR']
    wGR     = profs[tag]['wGR']
    T       = profs[tag]['T'] 
    extents = profs[tag]['extents']
    direc   = profs[tag]['direc'] 
    aS = profs[tag].get('aS',650.) 
    
    pot = scubic.sc(allIR=s, allGR=g, allIRw=wIR, allGRw=wGR)
    test = lda.lda(potential = pot, Temperature=T, a_s=aS, extents=extents, globalMu='halfMott', verbose=True, ignoreExtents=False)
    fig = lda.plotLine( test , line_direction=direc, extents=extents, x1lims=(-80.,80.), x2lims=(-50.,50.)) 
    print test.getRadius()/wIR
    print test.Number
    plt.close()
    fig.savefig('EtaF_data/profiles02/%03d.png'%tag, dpi=300)
# Out:
# 0
# OK: Bottom of the band has positive slope up to r111 = 10 um
# bandOrigin = -13.91
# band100 = -4.64
# 0.245369142754
# g0 = 4.32
# OK: Chemical potential is below evaporation threshold.
# OK: Chemical potential is below the bottom of the band along 100
# OK: Radial density profile along 111 decreases monotonically.
# 0.346081504702
# 155066.736351
# 1
# OK: Bottom of the band has positive slope up to r111 = 10 um
# bandOrigin = -13.91
# band100 = -4.64
# 0.245369142754
# g0 = 4.32
# OK: Chemical potential is below evaporation threshold.
# OK: Chemical potential is below the bottom of the band along 100
# OK: Radial density profile along 111 decreases monotonically.
# 0.346081504702
# 155066.736351
# 2
# OK: Bottom of the band has positive slope up to r111 = 10 um
# bandOrigin = -13.91
# band100 = -4.64
# 0.245369142754
# g0 = 4.32
# OK: Chemical potential is below evaporation threshold.
# OK: Chemical potential is below the bottom of the band along 100
# ...

# %% [markdown]
# ## Cell for obtaining the optimized value of g0

# %%
s = 7.
wIR = 50.
wGR = 41.666
aS = 650. 
T = 0.12 
extents = 80. 
optevap.optimal( s0=s, wL=wIR, wC=wGR, a_s=aS, T_Er=T, \
                                         extents=extents )
# Out:
# [3.8413373537346223,
#  2.4076656635097136,
#  886027.81175710855,
#  1.3838900384694264,
#  31.849529780564254,
#  0.63699059561128513,
#  1.0246440159709826]
